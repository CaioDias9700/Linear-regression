# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
Cerveja_date = pd.read_csv("Consumo_cerveja.csv",delimiter=';')

# %%
sns_plot = Cerveja_date.copy()
del sns_plot['fds']
sns.pairplot(sns_plot)

# %%
fig, axes = plt.subplots(figsize=(5, 15))
sns.boxplot(data=Cerveja_date['chuva'])
# Out:
# <AxesSubplot:>

# %%
Cerveja_date
# Out:
#            data  temp_media  temp_min  temp_max  chuva  fds  consumo
# 0    01/01/2015       27.30      23.9      32.5    0.0    0    25461
# 1    02/01/2015       27.02      24.5      33.5    0.0    0    28972
# 2    03/01/2015       24.82      22.4      29.9    0.0    1    30814
# 3    04/01/2015       23.98      21.5      28.6    1.2    1    29799
# 4    05/01/2015       23.82      21.0      28.3    0.0    0    28900
# ..          ...         ...       ...       ...    ...  ...      ...
# 360  27/12/2015       24.00      21.1      28.2   13.6    1    32307
# 361  28/12/2015       22.64      21.1      26.7    0.0    0    26095
# 362  29/12/2015       21.68      20.3      24.1   10.3    0    22309
# 363  30/12/2015       21.38      19.3      22.4    6.3    0    20467
# 364  31/12/2015       24.76      20.2      29.0    0.0    0    22446
#
# [365 rows x 7 columns]

# %%
Cerveja_date.describe()
# Out:
#        temp_media    temp_min    temp_max       chuva         fds  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000
# mean    21.226356   17.461370   26.611507    5.196712    0.284932
# std      3.180108    2.826185    4.317366   12.417844    0.452001
# min     12.900000   10.600000   14.500000    0.000000    0.000000
# 25%     19.020000   15.300000   23.800000    0.000000    0.000000
# 50%     21.380000   17.900000   26.900000    0.000000    0.000000
# 75%     23.280000   19.600000   29.400000    3.200000    1.000000
# max     28.860000   24.500000   36.500000   94.800000    1.000000
#
#             consumo
# count    365.000000
# mean   25401.367123
# std     4399.142703
# min    14343.000000
# 25%    22008.000000
# 50%    24867.000000
# 75%    28631.000000
# max    37937.000000

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(Cerveja_date.corr(),
            annot = True,
            fmt = '.2f')
plt.show()

# %%
del Cerveja_date['data']

# %%
X = Cerveja_date.copy()
y = Cerveja_date['consumo']

# %%
del X['consumo']

# %%
y
# Out:
# 0      25461
# 1      28972
# 2      30814
# 3      29799
# 4      28900
#        ...
# 360    32307
# 361    26095
# 362    22309
# 363    20467
# 364    22446
# Name: consumo, Length: 365, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([24883.58074291, 22924.55469774, 23799.10654104, 25400.86909323,
#        18348.9902872 , 25290.78346539, 24298.46215091, 19990.29619139,
#        31580.65622502, 21592.20241536, 20124.43539976, 26616.07691983,
#        24399.38332358, 25768.1761984 , 32738.29197279, 25460.29297046,
#        26105.8948692 , 28243.95864601, 22500.25986858, 25043.38034274,
#        25294.57008073, 20063.88720589, 29211.92203434, 27698.84489636,
#        20995.49255667, 25714.85241168, 23249.57935272, 24662.33178924,
#        25892.8204979 , 26789.06291009, 32094.2142931 , 24829.00576378,
#        30547.03572236, 28011.58714962, 25101.56424717, 25702.50485885,
#        23663.56812242, 32039.62874108, 28171.86631011, 25023.14867308,
#        21093.5233037 , 24648.69516348, 23820.38427701, 24020.90219163,
#        30332.11324153, 22972.15696832, 27608.08124381, 24411.45017813,
#        24842.78785167, 25166.58467562, 22873.58683506, 28680.72804317,
# ...

# %%
y_test
# Out:
# 195    28742
# 328    25119
# 336    28405
# 170    23055
# 151    16228
#        ...
# 359    21955
# 263    29829
# 165    19119
# 321    23614
# 136    28411
# Name: consumo, Length: 73, dtype: int64

# %%
print(reg.score(X_test, y_test)*100)
# Out:
# 67.6115773499209
